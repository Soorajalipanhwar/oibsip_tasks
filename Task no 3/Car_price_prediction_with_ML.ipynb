# %% [markdown]
# **OASIS INFOBYTE INTERNSHIP**
#
# **TASK:33 Car Price Prediction With Machine Learning**
#
# **BY:Sooraj AlI panhwar**

# %%
from IPython import display
display.Image("introduction.png")

# %% [markdown]
# **Importing the Libraries**

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# **Load the dataset**

# %%
# Load the dataset
df = pd.read_csv("car data.csv")

# %% [markdown]
# **Display the first few rows of the dataset**

# %%
# Display the first few rows of the dataset
print("First few rows of the dataset:")
print(df.head())
# Out:
# First few rows of the dataset:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %% [markdown]
# **Checking for null values**

# %%
# Checking for null values
print("\nNull values in the dataset:")
print(df.isnull().sum())
# Out:
# Null values in the dataset:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %% [markdown]
# **Dropping non-numeric columns except 'Selling_Price'**

# %%
# Dropping non-numeric columns except 'Selling_Price'
X = df[['Year', 'Present_Price', 'Driven_kms', 'Owner']]
y = df['Selling_Price']

# %% [markdown]
# **Split the data into training and testing sets**

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# **Initialize and train the Linear Regression model**

# %%
# Initialize and train the Linear Regression model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **Make predictions**

# %%
# Make predictions
y_pred = model.predict(X_test)

# %% [markdown]
# **Evaluate the model**

# %%
# Evaluate the model
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# %%
print("\nModel Evaluation Metrics:")
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R-squared (R2):", r2)
# Out:
# Model Evaluation Metrics:
# Mean Absolute Error (MAE): 1.261790093564186
# Mean Squared Error (MSE): 3.038508624473148
# Root Mean Squared Error (RMSE): 1.7431318436862853
# R-squared (R2): 0.8797930794745736

# %% [markdown]
# **Plot Actual vs Predicted values**

# %%
# Plot Actual vs Predicted values
plt.scatter(y_test, y_pred)
plt.xlabel('Actual Selling Price')
plt.ylabel('Predicted Selling Price')
plt.title('Actual vs Predicted Selling Prices')
plt.show()
